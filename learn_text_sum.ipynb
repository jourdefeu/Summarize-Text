# %% [markdown]
# BASEL, Switzerland (AP), Roger Federer advanced to the 14th Swiss Indoors final of his career by beating seventh-seeded Daniil Medvedev 6-1, 6-4 on Saturday. Seeking a ninth title at his hometown event, and a 99th overall, Federer will play 93th-ranked Marius Copil on Sunday. Federer dominated the 20th-ranked Medvedev and had his first match-point chance to break serve again at 5-1. He then dropped his serve to love, and let another match point slip in Medvedev's next service game by netting a backhand. He clinched on his fourth chance when Medvedev netted from the baseline. Copil upset expectations of a Federer final against Alexander Zverev in a 6-3, 6-7 (6), 6-4 win over the fifth-ranked German in the earlier semifinal. The Romanian aims for a first title after arriving at Basel without a career win over a top-10 opponent. Copil has two after also beating No. 6 Marin Cilic in the second round. Copil fired 26 aces past Zverev and never dropped serve, clinching after 2 1/2 hours with a forehand volley winner to break Zverev for the second time in the semifinal. He came through two rounds of qualifying last weekend to reach the Basel main draw, including beating Zverev's older brother, Mischa. Federer had an easier time than in his only previous match against Medvedev, a three-setter at Shanghai two weeks ago.

# %%
text = input("Enter your article: ")
# Out:
# Enter your article: BASEL, Switzerland (AP), Roger Federer advanced to the 14th Swiss Indoors final of his career by beating seventh-seeded Daniil Medvedev 6-1, 6-4 on Saturday. Seeking a ninth title at his hometown event, and a 99th overall, Federer will play 93th-ranked Marius Copil on Sunday. Federer dominated the 20th-ranked Medvedev and had his first match-point chance to break serve again at 5-1. He then dropped his serve to love, and let another match point slip in Medvedev's next service game by netting a backhand. He clinched on his fourth chance when Medvedev netted from the baseline. Copil upset expectations of a Federer final against Alexander Zverev in a 6-3, 6-7 (6), 6-4 win over the fifth-ranked German in the earlier semifinal. The Romanian aims for a first title after arriving at Basel without a career win over a top-10 opponent. Copil has two after also beating No. 6 Marin Cilic in the second round. Copil fired 26 aces past Zverev and never dropped serve, clinching after 2 1/2 hours with a forehand volley winner to break Zverev for the second time in the semifinal. He came through two rounds of qualifying last weekend to reach the Basel main draw, including beating Zverev's older brother, Mischa. Federer had an easier time than in his only previous match against Medvedev, a three-setter at Shanghai two weeks ago.

# %%
len(text)
# Out:
# 1331

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp(text)

# %%
tokens = [token.text.lower() for token in doc
         if not token.is_stop and
         not token.is_punct and
         token.text !='\n']

# %%
tokens
# Out:
# ['basel',
#  'switzerland',
#  'ap',
#  'roger',
#  'federer',
#  'advanced',
#  '14th',
#  'swiss',
#  'indoors',
#  'final',
#  'career',
#  'beating',
#  'seventh',
#  'seeded',
#  'daniil',
#  'medvedev',
#  '6',
#  '1',
#  '6',
#  '4',
#  'saturday',
#  'seeking',
#  'ninth',
#  'title',
#  'hometown',
#  'event',
#  '99th',
#  'overall',
#  'federer',
#  'play',
#  '93th',
#  'ranked',
#  'marius',
#  'copil',
#  'sunday',
#  'federer',
#  'dominated',
#  '20th',
#  'ranked',
#  'medvedev',
#  'match',
#  'point',
#  'chance',
#  'break',
#  'serve',
#  '5',
#  '1',
#  'dropped',
#  'serve',
#  'love',
#  'let',
#  'match',
#  'point',
#  'slip',
#  'medvedev',
#  'service',
#  'game',
#  'netting',
#  'backhand',
#  'clinched',
#  'fourth',
#  'chance',
#  'medvedev',
#  'netted',
#  'baseline',
#  'copil',
#  'upset',
#  'expectations',
#  'federer',
#  'final',
#  'alexander',
#  'zverev',
#  '6',
#  '3',
#  '6',
#  '7',
#  '6',
#  '6',
#  '4',
#  'win',
#  'fifth',
#  'ranked',
#  'german',
#  'earlier',
#  'semifinal',
#  'romanian',
#  'aims',
#  'title',
#  'arriving',
#  'basel',
#  'career',
#  'win',
#  'top-10',
#  'opponent',
#  'copil',
#  'beating',
#  '6',
#  'marin',
#  'cilic',
#  'second',
#  'round',
#  'copil',
#  'fired',
#  '26',
#  'aces',
#  'past',
#  'zverev',
#  'dropped',
#  'serve',
#  'clinching',
#  '2',
#  '1/2',
#  'hours',
#  'forehand',
#  'volley',
#  'winner',
#  'break',
#  'zverev',
#  'second',
#  'time',
#  'semifinal',
#  'came',
#  'rounds',
#  'qualifying',
#  'weekend',
#  'reach',
#  'basel',
#  'main',
#  'draw',
#  'including',
#  'beating',
#  'zverev',
#  'older',
#  'brother',
#  'mischa',
#  'federer',
#  'easier',
#  'time',
#  'previous',
#  'match',
#  'medvedev',
#  'setter',
#  'shanghai',
#  'weeks',
#  'ago']

# %%
tokens1=[]
stopwords=list(STOP_WORDS)
allowed_pos=['ADJ','PROPN','VERB','NOUN']
for token in doc:
    if token.text in stopwords or token.text in punctuation:
        continue
    if token.pos_ in allowed_pos:
        tokens1.append(token.text)

# %%
tokens1
# Out:
# ['BASEL',
#  'Switzerland',
#  'AP',
#  'Roger',
#  'Federer',
#  'advanced',
#  '14th',
#  'Swiss',
#  'Indoors',
#  'final',
#  'career',
#  'beating',
#  'seventh',
#  'seeded',
#  'Daniil',
#  'Medvedev',
#  'Saturday',
#  'Seeking',
#  'ninth',
#  'title',
#  'hometown',
#  'event',
#  '99th',
#  'overall',
#  'Federer',
#  'play',
#  '93th',
#  'ranked',
#  'Marius',
#  'Copil',
#  'Sunday',
#  'Federer',
#  'dominated',
#  'ranked',
#  'Medvedev',
#  'match',
#  'point',
#  'chance',
#  'break',
#  'serve',
#  'dropped',
#  'serve',
#  'love',
#  'let',
#  'match',
#  'point',
#  'slip',
#  'Medvedev',
#  'service',
#  'game',
#  'netting',
#  'backhand',
#  'clinched',
#  'fourth',
#  'chance',
#  'Medvedev',
#  'netted',
#  'baseline',
#  'Copil',
#  'upset',
#  'expectations',
#  'Federer',
#  'final',
#  'Alexander',
#  'Zverev',
#  'win',
#  'ranked',
#  'German',
#  'earlier',
#  'semifinal',
#  'Romanian',
#  'aims',
#  'title',
#  'arriving',
#  'Basel',
#  'career',
#  'win',
#  'top-10',
#  'opponent',
#  'Copil',
#  'beating',
#  'No',
#  'Marin',
#  'Cilic',
#  'second',
#  'round',
#  'Copil',
#  'fired',
#  'aces',
#  'Zverev',
#  'dropped',
#  'serve',
#  'clinching',
#  'hours',
#  'forehand',
#  'volley',
#  'winner',
#  'break',
#  'Zverev',
#  'second',
#  'time',
#  'semifinal',
#  'came',
#  'rounds',
#  'qualifying',
#  'weekend',
#  'reach',
#  'Basel',
#  'main',
#  'draw',
#  'including',
#  'beating',
#  'Zverev',
#  'older',
#  'brother',
#  'Mischa',
#  'Federer',
#  'easier',
#  'time',
#  'previous',
#  'match',
#  'Medvedev',
#  'setter',
#  'Shanghai',
#  'weeks']

# %%
from collections import Counter

# %%
word_freq=Counter(tokens)

# %%
max_freq=max(word_freq.values())

# %%
for word in word_freq.keys():
    word_freq[word]=word_freq[word]/max_freq

# %%
word_freq
# Out:
# Counter({'basel': 0.42857142857142855,
#          'switzerland': 0.14285714285714285,
#          'ap': 0.14285714285714285,
#          'roger': 0.14285714285714285,
#          'federer': 0.7142857142857143,
#          'advanced': 0.14285714285714285,
#          '14th': 0.14285714285714285,
#          'swiss': 0.14285714285714285,
#          'indoors': 0.14285714285714285,
#          'final': 0.2857142857142857,
#          'career': 0.2857142857142857,
#          'beating': 0.42857142857142855,
#          'seventh': 0.14285714285714285,
#          'seeded': 0.14285714285714285,
#          'daniil': 0.14285714285714285,
#          'medvedev': 0.7142857142857143,
#          '6': 1.0,
#          '1': 0.2857142857142857,
#          '4': 0.2857142857142857,
#          'saturday': 0.14285714285714285,
#          'seeking': 0.14285714285714285,
#          'ninth': 0.14285714285714285,
#          'title': 0.2857142857142857,
#          'hometown': 0.14285714285714285,
#          'event': 0.14285714285714285,
#          '99th': 0.14285714285714285,
#          'overall': 0.14285714285714285,
#          'play': 0.14285714285714285,
#          '93th': 0.14285714285714285,
#          'ranked': 0.42857142857142855,
#          'marius': 0.14285714285714285,
#          'copil': 0.5714285714285714,
#          'sunday': 0.14285714285714285,
#          'dominated': 0.14285714285714285,
#          '20th': 0.14285714285714285,
#          'match': 0.42857142857142855,
#          'point': 0.2857142857142857,
#          'chance': 0.2857142857142857,
#          'break': 0.2857142857142857,
#          'serve': 0.42857142857142855,
#          '5': 0.14285714285714285,
#          'dropped': 0.2857142857142857,
#          'love': 0.14285714285714285,
#          'let': 0.14285714285714285,
#          'slip': 0.14285714285714285,
#          'service': 0.14285714285714285,
#          'game': 0.14285714285714285,
#          'netting': 0.14285714285714285,
#          'backhand': 0.14285714285714285,
#          'clinched': 0.14285714285714285,
#          'fourth': 0.14285714285714285,
#          'netted': 0.14285714285714285,
#          'baseline': 0.14285714285714285,
#          'upset': 0.14285714285714285,
#          'expectations': 0.14285714285714285,
#          'alexander': 0.14285714285714285,
#          'zverev': 0.5714285714285714,
#          '3': 0.14285714285714285,
#          '7': 0.14285714285714285,
#          'win': 0.2857142857142857,
#          'fifth': 0.14285714285714285,
#          'german': 0.14285714285714285,
#          'earlier': 0.14285714285714285,
#          'semifinal': 0.2857142857142857,
#          'romanian': 0.14285714285714285,
#          'aims': 0.14285714285714285,
#          'arriving': 0.14285714285714285,
#          'top-10': 0.14285714285714285,
#          'opponent': 0.14285714285714285,
#          'marin': 0.14285714285714285,
#          'cilic': 0.14285714285714285,
#          'second': 0.2857142857142857,
#          'round': 0.14285714285714285,
#          'fired': 0.14285714285714285,
#          '26': 0.14285714285714285,
#          'aces': 0.14285714285714285,
#          'past': 0.14285714285714285,
#          'clinching': 0.14285714285714285,
#          '2': 0.14285714285714285,
#          '1/2': 0.14285714285714285,
#          'hours': 0.14285714285714285,
#          'forehand': 0.14285714285714285,
#          'volley': 0.14285714285714285,
#          'winner': 0.14285714285714285,
#          'time': 0.2857142857142857,
#          'came': 0.14285714285714285,
#          'rounds': 0.14285714285714285,
#          'qualifying': 0.14285714285714285,
#          'weekend': 0.14285714285714285,
#          'reach': 0.14285714285714285,
#          'main': 0.14285714285714285,
#          'draw': 0.14285714285714285,
#          'including': 0.14285714285714285,
#          'older': 0.14285714285714285,
#          'brother': 0.14285714285714285,
#          'mischa': 0.14285714285714285,
#          'easier': 0.14285714285714285,
#          'previous': 0.14285714285714285,
#          'setter': 0.14285714285714285,
#          'shanghai': 0.14285714285714285,
#          'weeks': 0.14285714285714285,
#          'ago': 0.14285714285714285})

# %%
sent_token = [sent.text for sent in doc.sents]

# %%
sent_token
# Out:
# ['BASEL, Switzerland (AP), Roger Federer advanced to the 14th Swiss Indoors final of his career by beating seventh-seeded Daniil Medvedev 6-1, 6-4 on Saturday.',
#  'Seeking a ninth title at his hometown event, and a 99th overall, Federer will play 93th-ranked Marius Copil on Sunday.',
#  'Federer dominated the 20th-ranked Medvedev and had his first match-point chance to break serve again at 5-1.',
#  "He then dropped his serve to love, and let another match point slip in Medvedev's next service game by netting a backhand.",
#  'He clinched on his fourth chance when Medvedev netted from the baseline.',
#  'Copil upset expectations of a Federer final against Alexander Zverev in a 6-3, 6-7 (6), 6-4 win over the fifth-ranked German in the earlier semifinal.',
#  'The Romanian aims for a first title after arriving at Basel without a career win over a top-10 opponent.',
#  'Copil has two after also beating No. 6 Marin Cilic in the second round.',
#  'Copil fired 26 aces past Zverev and never dropped serve, clinching after 2 1/2 hours with a forehand volley winner to break Zverev for the second time in the semifinal.',
#  "He came through two rounds of qualifying last weekend to reach the Basel main draw, including beating Zverev's older brother, Mischa.",
#  'Federer had an easier time than in his only previous match against Medvedev, a three-setter at Shanghai two weeks ago.']

# %%
sent_score = {}
for sent in sent_token:
    for word in sent.split():
        if word.lower() in word_freq.keys():
            if sent not in sent_score.keys():
                sent_score[sent] = word_freq[word]
            else:
                sent_score[sent] +=word_freq[word]
        print(word)
# Out:
# BASEL,
# Switzerland
# (AP),
# Roger
# Federer
# advanced
# to
# the
# 14th
# Swiss
# Indoors
# final
# of
# his
# career
# by
# beating
# seventh-seeded
# Daniil
# Medvedev
# 6-1,
# 6-4
# on
# Saturday.
# Seeking
# a
# ninth
# title
# at
# his
# hometown
# event,
# and
# a
# 99th
# overall,
# Federer
# will
# play
# 93th-ranked
# Marius
# Copil
# on
# Sunday.
# Federer
# dominated
# the
# 20th-ranked
# Medvedev
# and
# had
# his
# first
# match-point
# chance
# to
# break
# serve
# again
# at
# 5-1.
# He
# then
# dropped
# his
# serve
# to
# love,
# and
# let
# another
# match
# point
# slip
# in
# Medvedev's
# next
# service
# game
# by
# netting
# a
# backhand.
# He
# clinched
# on
# his
# fourth
# chance
# when
# Medvedev
# netted
# from
# the
# baseline.
# Copil
# upset
# expectations
# of
# a
# Federer
# final
# against
# Alexander
# Zverev
# in
# a
# 6-3,
# 6-7
# (6),
# 6-4
# win
# over
# the
# fifth-ranked
# German
# in
# the
# earlier
# semifinal.
# The
# Romanian
# aims
# for
# a
# first
# title
# after
# arriving
# at
# Basel
# without
# a
# career
# win
# over
# a
# top-10
# opponent.
# Copil
# has
# two
# after
# also
# beating
# No.
# 6
# Marin
# Cilic
# in
# the
# second
# round.
# Copil
# fired
# 26
# aces
# past
# Zverev
# and
# never
# dropped
# serve,
# clinching
# after
# 2
# 1/2
# hours
# with
# a
# forehand
# volley
# winner
# to
# break
# Zverev
# for
# the
# second
# time
# in
# the
# semifinal.
# He
# came
# through
# two
# rounds
# of
# qualifying
# last
# weekend
# to
# reach
# the
# Basel
# main
# draw,
# including
# beating
# Zverev's
# older
# brother,
# Mischa.
# Federer
# had
# an
# easier
# time
# than
# in
# his
# only
# previous
# match
# against
# Medvedev,
# a
# three-setter
# at
# Shanghai
# two
# weeks
# ago.

# %%
sent_score
# Out:
# {'BASEL, Switzerland (AP), Roger Federer advanced to the 14th Swiss Indoors final of his career by beating seventh-seeded Daniil Medvedev 6-1, 6-4 on Saturday.': 1.2857142857142856,
#  'Seeking a ninth title at his hometown event, and a 99th overall, Federer will play 93th-ranked Marius Copil on Sunday.': 0.857142857142857,
#  'Federer dominated the 20th-ranked Medvedev and had his first match-point chance to break serve again at 5-1.': 1.1428571428571428,
#  "He then dropped his serve to love, and let another match point slip in Medvedev's next service game by netting a backhand.": 2.1428571428571423,
#  'He clinched on his fourth chance when Medvedev netted from the baseline.': 0.7142857142857142,
#  'Copil upset expectations of a Federer final against Alexander Zverev in a 6-3, 6-7 (6), 6-4 win over the fifth-ranked German in the earlier semifinal.': 1.0,
#  'The Romanian aims for a first title after arriving at Basel without a career win over a top-10 opponent.': 1.2857142857142856,
#  'Copil has two after also beating No. 6 Marin Cilic in the second round.': 1.7142857142857144,
#  'Copil fired 26 aces past Zverev and never dropped serve, clinching after 2 1/2 hours with a forehand volley winner to break Zverev for the second time in the semifinal.': 2.7142857142857135,
#  "He came through two rounds of qualifying last weekend to reach the Basel main draw, including beating Zverev's older brother, Mischa.": 1.5714285714285712,
#  'Federer had an easier time than in his only previous match against Medvedev, a three-setter at Shanghai two weeks ago.': 1.1428571428571428}

# %%
import pandas as pd

# %%
pd.DataFrame(list(sent_score.items()),columns=['Sentence','Score'])
# Out:
#                                              Sentence     Score
# 0   BASEL, Switzerland (AP), Roger Federer advance...  1.285714
# 1   Seeking a ninth title at his hometown event, a...  0.857143
# 2   Federer dominated the 20th-ranked Medvedev and...  1.142857
# 3   He then dropped his serve to love, and let ano...  2.142857
# 4   He clinched on his fourth chance when Medvedev...  0.714286
# 5   Copil upset expectations of a Federer final ag...  1.000000
# 6   The Romanian aims for a first title after arri...  1.285714
# 7   Copil has two after also beating No. 6 Marin C...  1.714286
# 8   Copil fired 26 aces past Zverev and never drop...  2.714286
# 9   He came through two rounds of qualifying last ...  1.571429
# 10  Federer had an easier time than in his only pr...  1.142857

# %%
from heapq import nlargest

# %%
num_sentences=3
n=nlargest(num_sentences, sent_score, key=sent_score.get)

# %%
' '.join(n)
# Out:
# "Copil fired 26 aces past Zverev and never dropped serve, clinching after 2 1/2 hours with a forehand volley winner to break Zverev for the second time in the semifinal. He then dropped his serve to love, and let another match point slip in Medvedev's next service game by netting a backhand. Copil has two after also beating No. 6 Marin Cilic in the second round."

# %%
from transformers import pipeline

# %%
simmarizer=pipeline('summarization',model='t5-base',tokenizer='t5-base',framework='pt')

# %% [markdown]
# Roger Federer has revealed that organisers of the re-launched and condensed Davis Cup gave him three days to decide if he would commit to the controversial competition. Speaking at the Swiss Indoors tournament where he will play in Sundays final against Romanian qualifier Marius Copil, the world number three said that given the impossibly short time frame to make a decision, he opted out of any commitment. "They only left me three days to decide", Federer said. "I didn't to have time to consult with all the people I had to consult. "I could not make a decision in that time, so I told them to do what they wanted." The 20-time Grand Slam champion has voiced doubts about the wisdom of the one-week format to be introduced by organisers Kosmos, who have promised the International Tennis Federation up to $3 billion in prize money over the next quarter-century. The competition is set to feature 18 countries in the November 18-24 finals in Madrid next year, and will replace the classic home-and-away ties played four times per year for decades. Kosmos is headed by Barcelona footballer Gerard Pique, who is hoping fellow Spaniard Rafael Nadal will play in the upcoming event. Novak Djokovic has said he will give precedence to the ATP's intended re-launch of the defunct World Team Cup in January 2020, at various Australian venues. Major players feel that a big event in late November combined with one in January before the Australian Open will mean too much tennis and too little rest. Federer said earlier this month in Shanghai in that his chances of playing the Davis Cup were all but non-existent. "I highly doubt it, of course. We will see what happens," he said. "I do not think this was designed for me, anyhow. This was designed for the future generation of players." Argentina and Britain received wild cards to the new-look event, and will compete along with the four 2018 semi-finalists and the 12 teams who win qualifying rounds next February. "I don't like being under that kind of pressure," Federer said of the deadline Kosmos handed him.

# %%
text = input("Article: ")
# Out:
# Article: BASEL, Switzerland (AP), Roger Federer advanced to the 14th Swiss Indoors final of his career by beating seventh-seeded Daniil Medvedev 6-1, 6-4 on Saturday. Seeking a ninth title at his hometown event, and a 99th overall, Federer will play 93th-ranked Marius Copil on Sunday. Federer dominated the 20th-ranked Medvedev and had his first match-point chance to break serve again at 5-1. He then dropped his serve to love, and let another match point slip in Medvedev's next service game by netting a backhand. He clinched on his fourth chance when Medvedev netted from the baseline. Copil upset expectations of a Federer final against Alexander Zverev in a 6-3, 6-7 (6), 6-4 win over the fifth-ranked German in the earlier semifinal. The Romanian aims for a first title after arriving at Basel without a career win over a top-10 opponent. Copil has two after also beating No. 6 Marin Cilic in the second round. Copil fired 26 aces past Zverev and never dropped serve, clinching after 2 1/2 hours with a forehand volley winner to break Zverev for the second time in the semifinal. He came through two rounds of qualifying last weekend to reach the Basel main draw, including beating Zverev's older brother, Mischa. Federer had an easier time than in his only previous match against Medvedev, a three-setter at Shanghai two weeks ago.

# %%
summary = simmarizer(text,max_length=100,min_length=10,do_sample=False)

# %%
summary
# Out:
# [{'summary_text': 'Roger Federer beats seventh-seeded Daniil Medvedev 6-1, 6-4 on Saturday . he will play 93rd-ranked Marius Copil in the 14th Swiss Indoors final . Copil beats fifth-ranked Alexander Zverev in the earlier semifinal .'}]

# %%
print(summary[0]['summary_text'])
# Out:
# Roger Federer beats seventh-seeded Daniil Medvedev 6-1, 6-4 on Saturday . he will play 93rd-ranked Marius Copil in the 14th Swiss Indoors final . Copil beats fifth-ranked Alexander Zverev in the earlier semifinal .
